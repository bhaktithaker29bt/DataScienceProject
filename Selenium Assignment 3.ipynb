# %% [markdown]
# ### Selenium Assignment 3

# %%
  # ! pip install selenium

# %%
# import Libraries
import selenium
import pandas as pd
from selenium import webdriver
# lets firstt connect to web driver
driver = webdriver.Chrome(r"C:\Users\bhakti.thaker\Desktop\Datatrained\FLIPROBBO\Selenium Web sCrapping\chromedriver_win32\chromedriver.exe")

# %%
# alternative: upload this exe file into jupyter and now after running below stament also driver will be connected.
#driver= webdriver.Chrome("chromedriver.exe")

# %% [markdown]
# Ques1 > Write a python program which searches all the product under a particular product vertical
# from www.amazon.in. The product verticals to be searched will be taken as input from user.
# For e.g. If user input is ‘guitar’. Then search for guitars

# %%
url = 'https://www.amazon.in/'
driver.get(url)

# %%
user_inp=input("Enter the product you want to search:")
# Out:
# Enter the product you want to search:guitar

# %%
#finding element for job search bar
search_bar= driver.find_element_by_id('twotabsearchtextbox')
search_bar.clear()
search_bar.send_keys(user_inp)
search_button=driver.find_element_by_xpath('//div[@class="nav-search-submit nav-sprite"]/span/input')
search_button.click()

# %% [markdown]
# Question 2: In the above question, now scrape the following details of each product listed in first 3 pages
# of your search results and save it in a dataframe and csv. In case if any product vertical has
# less than 3 pages in search results then scrape all the products available under that product
# vertical. Details to be scraped are: "Brand Name", "Name of the Product", "Rating", "No. of
# Ratings", "Price", "Return/Exchange", "Expected Delivery", "Availability", "Other Details"
# and “Product URL”. In case, if any of the details are missing for any of the product then
# replace it by “-“

# %%
#Extracting all tags for Full Description
import time
urls=[]
for i in range(0,3):
    for j in driver.find_elements_by_xpath("//div[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-4']/a"):
        urls.append(j.get_attribute('href'))
    driver.find_element_by_xpath('//ul[@class="a-pagination"]/li/a').click()
    time.sleep(4)

# %%
urls
# Out:
# []

# %%
brand=[]
name_of_product=[]
rating=[]
number_of_rating=[]
price=[]
return_exchange=[]
expected_delivery=[]
availability=[]
other=[]
product_url=[]
import time
for i in url:
    for a in driver.find_elements_by_xpath('//td[@class="a-span3"]/span[@class="a-size-base a-text-bold"]'):
        brand.append(a.text)
#     for j in driver.find_elements_by_xpath('//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-4"]'):
#         title.append(j.text)
#     for l in driver.find_elements_by_xpath('//span[@class="a-price-whole"]'):
#         price.append(l.text)
    driver.find_element_by_xpath('//ul[@class="a-pagination"]/li/a').click()
    time.sleep(4)

# %%
brand

# %%
title
# Out:
# ['Kadence Frontier Jumbo Semi Acoustic Guitar With Die Cast Keys,Super Combo (Bag, 1 pack Strings, Strap, Picks, Capo, Tuner (black & stand)',
#  'Kadence Frontier Series, Natural Acoustic Guitar With Die Cast Keys Super Combo(Tuner,Capo,Bag,strap,strings and 3 picks)',
#  'Kadence Frontier Series,Blue Acoustic Guitar With Die Cast Keys Super Combo,Tuner,Capo,Bag,strap,strings,Stand and 3 picks)',
#  'Kadence Slowhand Premium Jumbo Size Semi Acoustic Guitar with Heavy Padded Bag, guitar cable, Pro Capo and Fibre guitar stand (Mahagony Wood)',
#  'Juârez Acoustic Guitar, 38 Inch Cutaway, 038C with Bag, Strings, Pick and Strap, Black',
#  'Juarez JRZ38C Acoustic Guitar, 38 Inch Cutaway with Bag (TBS Transparent Blue Sunburst)',
#  'Intern INT-38C Acoustic Guitar Kit, With Bag, Strings, Pick And Strap, Black',
#  'Juarez Acoustic Guitar, 38 Inch Curved Body Cutaway, 38CUR with Bag, Strings, Pick and Strap, Black',
#  'JUAREZ JRZ38C Right Handed Acoustic Guitar (Sunburst, 6 Strings)',
# ...

# %%
price
# Out:
# ['6,499',
#  '5,999',
#  '5,499',
#  '5,999',
#  '5,999',
#  '5,999',
#  '9,999',
#  '2,369',
#  '2,499',
#  '2,370',
#  '6,499',
#  '2,499',
#  '2,499',
#  '2,584',
#  '5,499',
#  '848',
#  '2,306',
#  '420',
#  '829',
#  '4,999',
#  '1,599',
#  '2,350',
#  '3,179',
#  '2,999',
#  '3,790',
#  '2,499',
#  '3,790',
#  '6,499',
#  '2,350',
#  '2,499',
#  '3,499',
#  '2,290',
#  '499',
#  '2,499',
#  '399',
#  '2,496',
#  '699',
#  '2,350',
#  '3,490',
#  '829',
#  '849',
#  '969',
#  '749',
#  '3,977',
#  '2,999',
#  '2,290',
#  '5,199',
#  '2,999',
#  '799',
#  '789',
#  '2,986',
#  '1,937',
#  '849',
#  '2,999',
#  '499',
#  '1,299',
#  '799',
#  '3,329',
#  '7,147',
#  '2,399',
#  '849',
#  '499',
#  '599',
#  '779']

# %%
# will check number of data extracted
print(len(title),len(price))
# Out:
# 60 64

# %%
# in list type. not in string so no need for eval()
import pandas as pd

df1 = pd.DataFrame(title,columns=['Title of Guitar'])
df1
# Out:
#                                       Title of Guitar
# 0   Kadence Frontier Jumbo Semi Acoustic Guitar Wi...
# 1   Kadence Frontier Series, Natural Acoustic Guit...
# 2   Kadence Frontier Series,Blue Acoustic Guitar W...
# 3   Kadence Slowhand Premium Jumbo Size Semi Acous...
# 4   Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...
# 5   Juarez JRZ38C Acoustic Guitar, 38 Inch Cutaway...
# 6   Intern INT-38C Acoustic Guitar Kit, With Bag, ...
# 7   Juarez Acoustic Guitar, 38 Inch Curved Body Cu...
# 8   JUAREZ JRZ38C Right Handed Acoustic Guitar (Su...
# 9   Intern 38-inch Cutaway Design Black Acoustic G...
# 10  Kadence Frontier Series,Black Semi Acoustic Gu...
# 11  SBU 4-String Acoustic Guitar Learning Kids Toy...
# 12  Intern INT-38C-RD-G Cutaway Right Handed Acous...
# 13  Royal Kids Guitar Toys for Kids 4-String Acous...
# 14  Crizer 4 String Guitar Children's Musical Inst...
# 15  Kadence Frontier Series, Acoustic Guitar With/...
# ...

# %%
df2 = pd.DataFrame(price,columns=['Price of Guitar'])
df2
# Out:
#    Price of Guitar
# 0            6,499
# 1            5,999
# 2            5,499
# 3            5,999
# 4            5,999
# ..             ...
# 59           2,399
# 60             849
# 61             499
# 62             599
# 63             779
#
# [64 rows x 1 columns]

# %%
result = pd.concat([df1, df2], axis=1, join='inner')
result
# Out:
#                                       Title of Guitar Price of Guitar
# 0   Kadence Frontier Jumbo Semi Acoustic Guitar Wi...           6,499
# 1   Kadence Frontier Series, Natural Acoustic Guit...           5,999
# 2   Kadence Frontier Series,Blue Acoustic Guitar W...           5,499
# 3   Kadence Slowhand Premium Jumbo Size Semi Acous...           5,999
# 4   Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...           5,999
# 5   Juarez JRZ38C Acoustic Guitar, 38 Inch Cutaway...           5,999
# 6   Intern INT-38C Acoustic Guitar Kit, With Bag, ...           9,999
# 7   Juarez Acoustic Guitar, 38 Inch Curved Body Cu...           2,369
# 8   JUAREZ JRZ38C Right Handed Acoustic Guitar (Su...           2,499
# 9   Intern 38-inch Cutaway Design Black Acoustic G...           2,370
# 10  Kadence Frontier Series,Black Semi Acoustic Gu...           6,499
# 11  SBU 4-String Acoustic Guitar Learning Kids Toy...           2,499
# ...

# %%
result = result.drop(result.index[50:],axis = 0)
result
# Out:
#                                       Title of Guitar Price of Guitar
# 0   Kadence Frontier Jumbo Semi Acoustic Guitar Wi...           6,499
# 1   Kadence Frontier Series, Natural Acoustic Guit...           5,999
# 2   Kadence Frontier Series,Blue Acoustic Guitar W...           5,499
# 3   Kadence Slowhand Premium Jumbo Size Semi Acous...           5,999
# 4   Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...           5,999
# 5   Juarez JRZ38C Acoustic Guitar, 38 Inch Cutaway...           5,999
# 6   Intern INT-38C Acoustic Guitar Kit, With Bag, ...           9,999
# 7   Juarez Acoustic Guitar, 38 Inch Curved Body Cu...           2,369
# 8   JUAREZ JRZ38C Right Handed Acoustic Guitar (Su...           2,499
# 9   Intern 38-inch Cutaway Design Black Acoustic G...           2,370
# 10  Kadence Frontier Series,Black Semi Acoustic Gu...           6,499
# 11  SBU 4-String Acoustic Guitar Learning Kids Toy...           2,499
# ...

# %% [markdown]
# #### Top 50 guitar list from amazon.in
